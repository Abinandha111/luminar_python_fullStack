# %% [markdown]
# ## SECTION 1: BASIC OPERATIONS & ACCESS

# %% [markdown]
# 1. SUM AND AVERAGE
#    - Problem: Given a list of numerical values (integers or floats), write a
#      function that calculates and returns both the total sum and average value.
#    - Input Example:  [10, 20, 30, 40, 50]
#    - Output Example: Sum = 150, Average = 30.0
#    - Constraint/Hint: Practice iterating through the list manually using a loop
#      before using standard library shortcuts.

# %%
numbers = [10,20,30,40,50]

def calculates():

    total=0

    for num in numbers:

        total+=num

    print(total)
    avg=total/len(list)
    print(avg)

calculates()
# Out:
# 150
# 30.0

# %% [markdown]
# 2. MIN & MAX FINDER
#    - Problem: Find the largest and smallest numbers in a list without using
#      built-in functions like min() or max().
#    - Input Example:  [3, 8, 1, 9, 4, 2]
#    - Output Example: Min = 1, Max = 9
#    - Constraint/Hint: Initialize min/max trackers with the first element of the list.

# %%
numbers = [3, 8, 1, 9, 4, 2]

smallest = numbers[0]
largest = numbers[0]

for num in numbers:

    if num < smallest:
        smallest = num

    if num > largest:
        largest = num

print("Min =", smallest)
print("Max =", largest)
# Out:
# Min = 1
# Max = 9

# %% [markdown]
# 3. ELEMENT SEARCH
#    - Problem: Write a program that checks whether a target value exists in a list
#      and returns its 0-based index. If the target does not exist, return -1.
#    - Input Example:  List = [15, 23, 42, 8, 16], Target = 42
#    - Output Example: Index = 2
#    - Constraint/Hint: Implement standard linear search.

# %%
numbers = [15, 23, 42, 8, 16]
target = 42

for num in range(len(numbers)):

    if numbers[num] == target:
        print("Index =", num)
        break
else:
    print("Index =", -1)
# Out:
# Index = 2

# %% [markdown]
# 4. FREQUENCY COUNTER
#    - Problem: Count how many times a specific element appears in a list.
#    - Input Example:  List = ['a', 'b', 'a', 'c', 'a', 'b'], Target = 'a'
#    - Output Example: Count = 3
#    - Constraint/Hint: Maintain a running tally while looping through elements.

# %%
letters = ['a', 'b', 'a', 'c', 'a', 'b']

target='a'

count=0

for i in letters:

    if i == target:

        count=count+1

print("count=",count)
# Out:
# count= 3

# %% [markdown]
# 5. LIST INVERSION (REVERSE)
#    - Problem: Reverse a list in-place (or construct a reversed version) without
#      using built-in library methods (e.g., .reverse() or [::-1]).
#    - Input Example:  [1, 2, 3, 4, 5]
#    - Output Example: [5, 4, 3, 2, 1]
#    - Constraint/Hint: Try using a two-pointer approach (swapping start and end elements).

# %%
numbers = [1, 2, 3, 4, 5]

start = 0
end = len(numbers) - 1

while start < end:

    numbers[start], numbers[end] = numbers[end], numbers[start]

    start = start + 1
    end = end - 1

print(numbers)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## SECTION 2: FILTERING & TRANSFORMATIONS

# %% [markdown]
# 6. EVEN FILTER
#    - Problem: Given a list of integers, create and return a new list containing
#      only the even numbers, maintaining their original order.
#    - Input Example:  [1, 2, 3, 4, 5, 6, 7, 8]
#    - Output Example: [2, 4, 6, 8]
#    - Constraint/Hint: Use the modulo operator (%) to check divisibility by 2.

# %%
numbers = [1, 2, 3, 4, 5, 6, 7, 8]

even_numbers = []

for num in numbers:
    if num % 2 == 0:
        even_numbers.append(num)

print(even_numbers)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# 7. VALUE TRANSFORMATION (SQUARING)
#    - Problem: Take a list of numbers and return a new list where every number is
#      squared.
#    - Input Example:  [2, 3, 5, 7]
#    - Output Example: [4, 9, 25, 49]
#    - Constraint/Hint: Create a new output list and append squared values.

# %%
numbers = [2, 3, 5, 7]

squared_numbers = []

for num in numbers:
    squared_numbers.append(num * num)

print(squared_numbers)
# Out:
# [4, 9, 25, 49]

# %% [markdown]
# 8. DEDUPLICATION (REMOVE DUPLICATES)
#    - Problem: Remove all duplicate values from a list while preserving the
#      original order of elements.
#    - Input Example:  [4, 5, 4, 1, 2, 5, 3]
#    - Output Example: [4, 5, 1, 2, 3]
#    - Constraint/Hint: Use a secondary list or tracking set to detect prior occurrences.

# %%
numbers = [4, 5, 4, 1, 2, 5, 3]

new_list = []

for num in numbers:
    if num not in new_list:
        new_list.append(num)

print(new_list)
# Out:
# [4, 5, 1, 2, 3]

# %% [markdown]
# 9. REMOVE EMPTY ITEMS
#    - Problem: Given a list containing valid items along with empty/null items
#      (such as empty strings, None, or null), return a cleaned list containing
#      only non-empty data.
#    - Input Example:  ["apple", "", "banana", None, "cherry", ""]
#    - Output Example: ["apple", "banana", "cherry"]
#    - Constraint/Hint: Check truthiness or explicitly filter out empty string / None.

# %%
items = ["apple", "", "banana", None, "cherry", ""]

new_list = []

for item in items:
    if item:
        new_list.append(item)

print(new_list)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# 10. THRESHOLD COUNTER
#     - Problem: Count how many elements in a numerical list are strictly greater
#       than a given threshold number k.
#     - Input Example:  List = [12, 45, 6, 89, 23, 5], Threshold k = 20
#     - Output Example: Count = 3 (elements: 45, 89, 23)
#     - Constraint/Hint: Compare each element against k inside a loop

# %%
numbers = [12, 45, 6, 89, 23, 5]
k = 20

count = 0

for num in numbers:
    if num > k:
        count = count + 1

print("Count =", count)
# Out:
# Count = 3

# %% [markdown]
# ## SECTION 3: MULTI-LIST LOGIC & MANIPULATION

# %% [markdown]
# 11. MERGE TWO SORTED LISTS
#     - Problem: Combine two pre-sorted lists into a single, fully sorted list.
#     - Input Example:  List A = [1, 3, 5], List B = [2, 4, 6]
#     - Output Example: [1, 2, 3, 4, 5, 6]
#     - Constraint/Hint: Compare elements from both lists step-by-step using pointers.

# %%
a = [1, 3, 5]
b = [2, 4, 6]

result = []

i = 0
j = 0

while i < len(a) and j < len(b):

    if a[i] < b[j]:
        result.append(a[i])
        i = i + 1
    else:
        result.append(b[j])
        j = j + 1

while i < len(a):
    result.append(a[i])
    i = i + 1

while j < len(b):
    result.append(b[j])
    j = j + 1

print(result)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 12. FIND COMMON ELEMENTS (INTERSECTION)
#     - Problem: Given two separate lists, return a list containing only the
#       elements shared by both (without duplicates in the output).
#     - Input Example:  List A = [1, 2, 3, 4], List B = [3, 4, 5, 6]
#     - Output Example: [3, 4]
#     - Constraint/Hint: Check presence of elements from List A in List B.

# %%
a = [1, 2, 3, 4]
b = [3, 4, 5, 6]

result = []

for num in a:
    if num in b and num not in result:
        result.append(num)

print(result)
# Out:
# [3, 4]

# %% [markdown]
# 13. LIST SPLITTING
#     - Problem: Write a function that splits a single list into two halves. If
#       the list length is odd, the first half should take the extra element.
#     - Input Example:  [10, 20, 30, 40, 50]
#     - Output Example: Half 1 = [10, 20, 30], Half 2 = [40, 50]
#     - Constraint/Hint: Calculate the midpoint index using integer division.

# %%
numbers = [10, 20, 30, 40, 50]

def split_list():

    mid = (len(numbers) + 1) // 2

    half1 = numbers[:mid]
    half2 = numbers[mid:]

    print("Half 1 =", half1)
    print("Half 2 =", half2)

split_list()
# Out:
# Half 1 = [10, 20, 30]
# Half 2 = [40, 50]

# %% [markdown]
# 14. LIST ROTATION
#     - Problem: Rotate elements of a list to the right by k positions.
#     - Input Example:  List = [1, 2, 3, 4, 5], k = 2
#     - Output Example: [4, 5, 1, 2, 3]
#     - Constraint/Hint: Use slicing or pop/insert loops. Handle cases where k > length.

# %%
numbers = [1, 2, 3, 4, 5]
k = 2

for i in range(k):
    last = numbers.pop()
    numbers.insert(0, last)

print(numbers)
# Out:
# [4, 5, 1, 2, 3]

# %% [markdown]
# 15. MOVE ZEROS TO END
#     - Problem: Shift all zero values in an integer list to the end while
#       maintaining the relative order of non-zero elements.
#     - Input Example:  [0, 1, 0, 3, 12]
#     - Output Example: [1, 3, 12, 0, 0]
#     - Constraint/Hint: Keep a index pointer for non-zero insertion.

# %%
numbers = [0, 1, 0, 3, 12]

index = 0

for num in numbers:
    if num != 0:
        numbers[index] = num
        index = index + 1

while index < len(numbers):
    numbers[index] = 0
    index = index + 1

print(numbers)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ## SECTION 4: APPLIED LOGIC & STRING PROCESSING

# %% [markdown]
# 16. PALINDROME CHECKER
#     - Problem: Determine whether a list reads the same forwards and backwards.
#     - Input Example:  [1, 2, 3, 2, 1]
#     - Output Example: True
#     - Constraint/Hint: Compare element at index i with index (length - 1 - i).
#
#
#     - Output Example: [('a', 3), ('b', 2), ('c', 1), ('a', 2)]
#     - Constraint/Hint: Iterate while tracking the current element and its count.

# %%
numbers = [1, 2, 3, 2, 1]

is_palindrome = True

for i in range(len(numbers) // 2):

    if numbers[i] != numbers[len(numbers) - 1 - i]:
        is_palindrome = False
        break

print(is_palindrome)
# Out:
# True

# %% [markdown]
# 17. SECOND LARGEST NUMBER
#     - Problem: Find the second largest number in an unsorted list without
#       sorting the entire list.
#     - Input Example:  [12, 35, 1, 10, 34, 1]
#     - Output Example: 34
#     - Constraint/Hint: Track two variables: largest and second_largest.

# %%
numbers = [12, 35, 1, 10, 34, 1]

largest = numbers[0]
second_largest = numbers[0]

for num in numbers:

    if num > largest:
        second_largest = largest
        largest = num

    elif num > second_largest and num != largest:
        second_largest = num

print("Second largest =", second_largest)
# Out:
# Second largest = 34

# %% [markdown]
# 18. AVERAGE WORD LENGTH
#     - Problem: Given a list of string words, calculate the average character
#       length of the words in the list.
#     - Input Example:  ["cat", "banana", "elephant", "dog"]
#     - Output Example: 5.0  (Total characters = 20, Words = 4)
#     - Constraint/Hint: Sum the length of each string and divide by total words count.

# %%
words = ["cat", "banana", "elephant", "dog"]

total = 0

for word in words:
    total = total + len(word)

average = total / len(words)

print(average)
# Out:
# 5.0

# %% [markdown]
# 19. FLATTEN 2D LIST
#     - Problem: Convert a 2D matrix/list (list of lists) into a 1D flat list.
#     - Input Example:  [[1, 2], [3, 4], [5, 6]]
#     - Output Example: [1, 2, 3, 4, 5, 6]
#     - Constraint/Hint: Use nested loops or list comprehension to extract elements.

# %%
numbers = [[1, 2], [3, 4], [5, 6]]

flat_list = []

for row in numbers:
    for num in row:
        flat_list.append(num)

print(flat_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 20. RUN-LENGTH ENCODER
#     - Problem: Compress consecutive repeating elements in a list into pairs
#       of (element, consecutive_count).
#     - Input Example:  ['a', 'a', 'a', 'b', 'b', 'c', 'a', 'a']

# %%
letters = ['a', 'a', 'a', 'b', 'b', 'c', 'a', 'a']

result = []

current = letters[0]
count = 1

for i in range(1, len(letters)):

    if letters[i] == current:
        count = count + 1

    else:
        result.append((current, count))
        current = letters[i]
        count = 1

result.append((current, count))

print(result)
# Out:
# [('a', 3), ('b', 2), ('c', 1), ('a', 2)]
